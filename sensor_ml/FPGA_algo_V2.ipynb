# %%
# Just a place to write pseudocode for an improved version of the FPGA algo to handle pileup

# idea is to use integral of signal for threshold detection, because gaussian noise should generally cancel
#     need to derive p(noise) given some voltage range
# keep track of list of recent pulses s.t. that can calculate a "moving baseline" on top of the main voltage baseline.
# voltage integral should have this subtracted off to estimate the photon energy

# this is going to be slow...
#   needs for loop, dynamic lists, integration over multiple previous and (potential) current pulse
#   basically requires matrix math at every single point... is going to be slow, O(n**2) or O(n*rate)

# gauss_integral = 0
# kernel = pulse()
# recent_pulse_list   # List of indeces of start of recent pulses.. List so can easily modify
# 
# for v in trace:
#     gauss_integral += v
#
#     if gauss_integral > threshold:
